# %%
import config
import requests
import time
from pprint import pprint
from pymongo import MongoClient
from tqdm.auto import tqdm

# %%
BASE_URL = 'https://fantasy.premierleague.com/api/'
API_DATA = requests.get(BASE_URL+'bootstrap-static/').json()

# %%
def get_fixtures():
    '''Get all fixtures and update MongoDB'''

    # get all fixture data
    data = requests.get(BASE_URL+'fixtures/').json()

    for fixture in data:
        for key in ['code', 'finished_provisional', 'minutes',
                    'provisional_start_time', 'started', 'stats', 'pulse_id']:
            del fixture[key]

    API_DATA['fixtures'] = data

    return True

# %%
get_fixtures()
# Out:
# True

# %%
# Bootstrap-static data
pprint(API_DATA, depth=1)
# Out:
# {'element_stats': [...],
#  'element_types': [...],
#  'elements': [...],
#  'events': [...],
#  'fixtures': [...],
#  'game_settings': {...},
#  'phases': [...],
#  'teams': [...],
#  'total_players': 11431471}

# %%
# connect to MongoDB
client = MongoClient(f'mongodb+srv://{config.username}:{config.password}'
                     f'@{config.database}/?retryWrites=true&w=majority')
db = client.get_database('raw_2022-23')

# %%
def get_bootstrap_static():
    '''Get all data from the bootstrap-static endpoint and update MongoDB
    
    Bootstrap-static data includes the following:
      - elements (players)
      - element_types (positions)
      - events (gameweeks)
      - teams
    '''

    # delete unnecessary keys
    for key in ['element_stats', 'game_settings', 'total_players', 'phases']:
        del API_DATA[key]

    # iterate over each endpoint
    for endpoint in API_DATA.keys():
        print(f'Updating {endpoint.upper()} data')
        data = API_DATA[endpoint].copy()

        # get number of docs, cols in collection
        n_docs = db.get_collection(endpoint).count_documents({})
        n_cols = len(db[endpoint].find_one({})) if n_docs else 0
        print(f'{endpoint} shape: {n_docs} docs X {n_cols} cols')

        # update docs in each collection
        for row in tqdm(data):
            row['_id'] = row.pop('id')  # rename id field
            filter_query = {'_id': row['_id']}
            update_data = {'$set': row}
            db[endpoint].update_one(filter_query, update_data, upsert=True)

        # print number of new docs, cols
        print(f'Added {db[endpoint].count_documents({}) - n_docs} new docs')
        print(f'Added {len(db[endpoint].find_one({})) - n_cols} new cols\n')

    return True

# %%
get_bootstrap_static()
# Out:
# Updating events data
# events shape: 38 docs X 23 cols
#   0%|          | 0/38 [00:00<?, ?it/s]
# Added 0 new docs
# Added 0 new cols
#
# Updating teams data
# teams shape: 20 docs X 21 cols
#   0%|          | 0/20 [00:00<?, ?it/s]
# Added 0 new docs
# Added 0 new cols
#
# Updating elements data
# elements shape: 764 docs X 88 cols
#   0%|          | 0/764 [00:00<?, ?it/s]
# Added 0 new docs
# Added 0 new cols
#
# Updating element_types data
# element_types shape: 4 docs X 11 cols
#   0%|          | 0/4 [00:00<?, ?it/s]
# Added 0 new docs
# Added 0 new cols
#
# Updating fixtures data
# fixtures shape: 380 docs X 10 cols
#   0%|          | 0/380 [00:00<?, ?it/s]
# Added 0 new docs
# Added 0 new cols
# True

# %%
def get_element_summary():
    '''Get all past season or gameweek info for a given player_id,
       wait between requests to avoid API rate limit'''
    
    # iterate through all players
    for element in tqdm(API_DATA['elements']):
        element_id = element['id']

        success = False
        # try until a result is returned
        while not success:
            try:
                # send GET request to BASE_URL/api/element-summary/{PID}/
                data = requests.get(
                    BASE_URL + 'element-summary/' + str(element_id) + '/').json()
                success = True
            except:
                # wait a bit to avoid API rate limits, if needed
                time.sleep(.3)

        # to do update MongoDB
        for row in data:
            db['element_gameweek_history']
    
    return data
# Out:
# {'fixtures': [...], 'history': [...], 'history_past': [...]}

# %%
get_element_summary(1)['history']
# Out:
# [{'element': 1,
#   'fixture': 1,
#   'opponent_team': 7,
#   'total_points': 0,
#   'was_home': False,
#   'kickoff_time': '2022-08-05T19:00:00Z',
#   'team_h_score': 0,
#   'team_a_score': 2,
#   'round': 1,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 45,
#   'transfers_balance': 0,
#   'selected': 23970,
#   'transfers_in': 0,
#   'transfers_out': 0},
#  {'element': 1,
#   'fixture': 11,
#   'opponent_team': 10,
#   'total_points': 0,
#   'was_home': True,
#   'kickoff_time': '2022-08-13T14:00:00Z',
#   'team_h_score': 4,
#   'team_a_score': 2,
#   'round': 2,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 44,
#   'transfers_balance': -5169,
#   'selected': 24193,
#   'transfers_in': 1361,
#   'transfers_out': 6530},
#  {'element': 1,
#   'fixture': 21,
#   'opponent_team': 3,
#   'total_points': 0,
#   'was_home': False,
#   'kickoff_time': '2022-08-20T16:30:00Z',
#   'team_h_score': 0,
#   'team_a_score': 3,
#   'round': 3,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 44,
#   'transfers_balance': -4337,
#   'selected': 20960,
#   'transfers_in': 879,
#   'transfers_out': 5216},
#  {'element': 1,
#   'fixture': 31,
#   'opponent_team': 9,
#   'total_points': 0,
#   'was_home': True,
#   'kickoff_time': '2022-08-27T16:30:00Z',
#   'team_h_score': 2,
#   'team_a_score': 1,
#   'round': 4,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 43,
#   'transfers_balance': -2988,
#   'selected': 18825,
#   'transfers_in': 577,
#   'transfers_out': 3565},
#  {'element': 1,
#   'fixture': 41,
#   'opponent_team': 2,
#   'total_points': 0,
#   'was_home': True,
#   'kickoff_time': '2022-08-31T18:30:00Z',
#   'team_h_score': 2,
#   'team_a_score': 1,
#   'round': 5,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 43,
#   'transfers_balance': -1611,
#   'selected': 17790,
#   'transfers_in': 405,
#   'transfers_out': 2016},
#  {'element': 1,
#   'fixture': 56,
#   'opponent_team': 14,
#   'total_points': 0,
#   'was_home': False,
#   'kickoff_time': '2022-09-04T15:30:00Z',
#   'team_h_score': 3,
#   'team_a_score': 1,
#   'round': 6,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': -1207,
#   'selected': 17133,
#   'transfers_in': 516,
#   'transfers_out': 1723},
#  {'element': 1,
#   'fixture': 72,
#   'opponent_team': 4,
#   'total_points': 0,
#   'was_home': False,
#   'kickoff_time': '2022-09-18T11:00:00Z',
#   'team_h_score': 0,
#   'team_a_score': 3,
#   'round': 8,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': -445,
#   'selected': 16837,
#   'transfers_in': 114,
#   'transfers_out': 559},
#  {'element': 1,
#   'fixture': 81,
#   'opponent_team': 18,
#   'total_points': 0,
#   'was_home': True,
#   'kickoff_time': '2022-10-01T11:30:00Z',
#   'team_h_score': 3,
#   'team_a_score': 1,
#   'round': 9,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': -1572,
#   'selected': 15362,
#   'transfers_in': 64,
#   'transfers_out': 1636},
#  {'element': 1,
#   'fixture': 91,
#   'opponent_team': 12,
#   'total_points': 0,
#   'was_home': True,
#   'kickoff_time': '2022-10-09T15:30:00Z',
#   'team_h_score': 3,
#   'team_a_score': 2,
#   'round': 10,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': -828,
#   'selected': 14630,
#   'transfers_in': 148,
#   'transfers_out': 976},
#  {'element': 1,
#   'fixture': 104,
#   'opponent_team': 11,
#   'total_points': 0,
#   'was_home': False,
#   'kickoff_time': '2022-10-16T13:00:00Z',
#   'team_h_score': 0,
#   'team_a_score': 1,
#   'round': 11,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': -229,
#   'selected': 14586,
#   'transfers_in': 227,
#   'transfers_out': 456},
#  {'element': 1,
#   'fixture': 127,
#   'opponent_team': 17,
#   'total_points': 0,
#   'was_home': False,
#   'kickoff_time': '2022-10-23T13:00:00Z',
#   'team_h_score': 1,
#   'team_a_score': 1,
#   'round': 13,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': -94,
#   'selected': 14516,
#   'transfers_in': 166,
#   'transfers_out': 260},
#  {'element': 1,
#   'fixture': 131,
#   'opponent_team': 16,
#   'total_points': 1,
#   'was_home': True,
#   'kickoff_time': '2022-10-30T14:00:00Z',
#   'team_h_score': 5,
#   'team_a_score': 0,
#   'round': 14,
#   'minutes': 27,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 2,
#   'influence': '2.4',
#   'creativity': '1.6',
#   'threat': '0.0',
#   'ict_index': '0.4',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.01',
#   'expected_goal_involvements': '0.01',
#   'expected_goals_conceded': '0.04',
#   'value': 42,
#   'transfers_balance': -247,
#   'selected': 14398,
#   'transfers_in': 137,
#   'transfers_out': 384},
#  {'element': 1,
#   'fixture': 142,
#   'opponent_team': 6,
#   'total_points': 0,
#   'was_home': False,
#   'kickoff_time': '2022-11-06T12:00:00Z',
#   'team_h_score': 0,
#   'team_a_score': 1,
#   'round': 15,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': -161,
#   'selected': 14350,
#   'transfers_in': 156,
#   'transfers_out': 317},
#  {'element': 1,
#   'fixture': 160,
#   'opponent_team': 20,
#   'total_points': 1,
#   'was_home': False,
#   'kickoff_time': '2022-11-12T19:45:00Z',
#   'team_h_score': 0,
#   'team_a_score': 2,
#   'round': 16,
#   'minutes': 1,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 3,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': -168,
#   'selected': 14299,
#   'transfers_in': 171,
#   'transfers_out': 339},
#  {'element': 1,
#   'fixture': 161,
#   'opponent_team': 19,
#   'total_points': 0,
#   'was_home': True,
#   'kickoff_time': '2022-12-26T20:00:00Z',
#   'team_h_score': 3,
#   'team_a_score': 1,
#   'round': 17,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': 40,
#   'selected': 14551,
#   'transfers_in': 663,
#   'transfers_out': 623},
#  {'element': 1,
#   'fixture': 172,
#   'opponent_team': 5,
#   'total_points': 0,
#   'was_home': False,
#   'kickoff_time': '2022-12-31T17:30:00Z',
#   'team_h_score': 2,
#   'team_a_score': 4,
#   'round': 18,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': -107,
#   'selected': 14533,
#   'transfers_in': 113,
#   'transfers_out': 220},
#  {'element': 1,
#   'fixture': 181,
#   'opponent_team': 15,
#   'total_points': 0,
#   'was_home': True,
#   'kickoff_time': '2023-01-03T19:45:00Z',
#   'team_h_score': 0,
#   'team_a_score': 0,
#   'round': 19,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': -128,
#   'selected': 14456,
#   'transfers_in': 70,
#   'transfers_out': 198},
#  {'element': 1,
#   'fixture': 199,
#   'opponent_team': 18,
#   'total_points': 0,
#   'was_home': False,
#   'kickoff_time': '2023-01-15T16:30:00Z',
#   'team_h_score': 0,
#   'team_a_score': 2,
#   'round': 20,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': -131,
#   'selected': 14425,
#   'transfers_in': 108,
#   'transfers_out': 239},
#  {'element': 1,
#   'fixture': 201,
#   'opponent_team': 14,
#   'total_points': 0,
#   'was_home': True,
#   'kickoff_time': '2023-01-22T16:30:00Z',
#   'team_h_score': 3,
#   'team_a_score': 2,
#   'round': 21,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': -117,
#   'selected': 14379,
#   'transfers_in': 68,
#   'transfers_out': 185},
#  {'element': 1,
#   'fixture': 214,
#   'opponent_team': 6,
#   'total_points': 0,
#   'was_home': False,
#   'kickoff_time': '2023-02-03T20:00:00Z',
#   'team_h_score': 0,
#   'team_a_score': 0,
#   'round': 22,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': 207,
#   'selected': 14703,
#   'transfers_in': 481,
#   'transfers_out': 274},
#  {'element': 1,
#   'fixture': 224,
#   'opponent_team': 16,
#   'total_points': 1,
#   'was_home': True,
#   'kickoff_time': '2023-02-11T15:00:00Z',
#   'team_h_score': 2,
#   'team_a_score': 0,
#   'round': 23,
#   'minutes': 1,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 3,
#   'influence': '0.4',
#   'creativity': '0.1',
#   'threat': '0.0',
#   'ict_index': '0.1',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': 78,
#   'selected': 14828,
#   'transfers_in': 234,
#   'transfers_out': 156},
#  {'element': 1,
#   'fixture': 233,
#   'opponent_team': 5,
#   'total_points': 0,
#   'was_home': False,
#   'kickoff_time': '2023-02-18T15:00:00Z',
#   'team_h_score': 0,
#   'team_a_score': 1,
#   'round': 24,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': 48,
#   'selected': 14910,
#   'transfers_in': 179,
#   'transfers_out': 131},
#  {'element': 1,
#   'fixture': 244,
#   'opponent_team': 20,
#   'total_points': 0,
#   'was_home': True,
#   'kickoff_time': '2023-02-24T20:00:00Z',
#   'team_h_score': 1,
#   'team_a_score': 1,
#   'round': 25,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': 122,
#   'selected': 15236,
#   'transfers_in': 330,
#   'transfers_out': 208},
#  {'element': 1,
#   'fixture': 253,
#   'opponent_team': 4,
#   'total_points': 1,
#   'was_home': False,
#   'kickoff_time': '2023-03-06T20:00:00Z',
#   'team_h_score': 3,
#   'team_a_score': 2,
#   'round': 26,
#   'minutes': 7,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 1,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 5,
#   'influence': '4.2',
#   'creativity': '0.3',
#   'threat': '0.0',
#   'ict_index': '0.5',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.35',
#   'value': 42,
#   'transfers_balance': -71,
#   'selected': 15056,
#   'transfers_in': 151,
#   'transfers_out': 222},
#  {'element': 1,
#   'fixture': 264,
#   'opponent_team': 1,
#   'total_points': 0,
#   'was_home': True,
#   'kickoff_time': '2023-03-12T14:00:00Z',
#   'team_h_score': 0,
#   'team_a_score': 3,
#   'round': 27,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': -250,
#   'selected': 14820,
#   'transfers_in': 85,
#   'transfers_out': 335},
#  {'element': 1,
#   'fixture': 282,
#   'opponent_team': 3,
#   'total_points': 1,
#   'was_home': False,
#   'kickoff_time': '2023-04-01T14:00:00Z',
#   'team_h_score': 2,
#   'team_a_score': 1,
#   'round': 29,
#   'minutes': 8,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 3,
#   'influence': '0.8',
#   'creativity': '0.4',
#   'threat': '0.0',
#   'ict_index': '0.1',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.26',
#   'value': 42,
#   'transfers_balance': 27,
#   'selected': 14836,
#   'transfers_in': 163,
#   'transfers_out': 136},
#  {'element': 1,
#   'fixture': 293,
#   'opponent_team': 19,
#   'total_points': 2,
#   'was_home': True,
#   'kickoff_time': '2023-04-08T14:00:00Z',
#   'team_h_score': 0,
#   'team_a_score': 1,
#   'round': 30,
#   'minutes': 67,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 1,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 19,
#   'influence': '20.2',
#   'creativity': '32.4',
#   'threat': '6.0',
#   'ict_index': '5.9',
#   'starts': 1,
#   'expected_goals': '0.02',
#   'expected_assists': '0.11',
#   'expected_goal_involvements': '0.13',
#   'expected_goals_conceded': '0.19',
#   'value': 42,
#   'transfers_balance': 9,
#   'selected': 14876,
#   'transfers_in': 129,
#   'transfers_out': 120},
#  {'element': 1,
#   'fixture': 303,
#   'opponent_team': 8,
#   'total_points': 0,
#   'was_home': False,
#   'kickoff_time': '2023-04-15T14:00:00Z',
#   'team_h_score': 1,
#   'team_a_score': 3,
#   'round': 31,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': 222,
#   'selected': 15135,
#   'transfers_in': 320,
#   'transfers_out': 98},
#  {'element': 1,
#   'fixture': 316,
#   'opponent_team': 11,
#   'total_points': 0,
#   'was_home': True,
#   'kickoff_time': '2023-04-22T11:30:00Z',
#   'team_h_score': 2,
#   'team_a_score': 1,
#   'round': 32,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': 41,
#   'selected': 15302,
#   'transfers_in': 202,
#   'transfers_out': 161},
#  {'element': 1,
#   'fixture': 321,
#   'opponent_team': 2,
#   'total_points': 1,
#   'was_home': False,
#   'kickoff_time': '2023-04-25T18:45:00Z',
#   'team_h_score': 1,
#   'team_a_score': 0,
#   'round': 33,
#   'minutes': 22,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 4,
#   'influence': '6.2',
#   'creativity': '1.2',
#   'threat': '2.0',
#   'ict_index': '0.9',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.26',
#   'value': 42,
#   'transfers_balance': 0,
#   'selected': 15223,
#   'transfers_in': 130,
#   'transfers_out': 130},
#  {'element': 1,
#   'fixture': 336,
#   'opponent_team': 13,
#   'total_points': 0,
#   'was_home': True,
#   'kickoff_time': '2023-04-30T13:00:00Z',
#   'team_h_score': 1,
#   'team_a_score': 2,
#   'round': 34,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': 142,
#   'selected': 15539,
#   'transfers_in': 306,
#   'transfers_out': 164},
#  {'element': 1,
#   'fixture': 276,
#   'opponent_team': 12,
#   'total_points': 2,
#   'was_home': False,
#   'kickoff_time': '2023-05-03T19:00:00Z',
#   'team_h_score': 1,
#   'team_a_score': 0,
#   'round': 34,
#   'minutes': 90,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 1,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 17,
#   'influence': '22.2',
#   'creativity': '15.4',
#   'threat': '2.0',
#   'ict_index': '4.0',
#   'starts': 1,
#   'expected_goals': '0.04',
#   'expected_assists': '0.07',
#   'expected_goal_involvements': '0.11',
#   'expected_goals_conceded': '1.73',
#   'value': 42,
#   'transfers_balance': 142,
#   'selected': 15539,
#   'transfers_in': 306,
#   'transfers_out': 164},
#  {'element': 1,
#   'fixture': 343,
#   'opponent_team': 10,
#   'total_points': 0,
#   'was_home': True,
#   'kickoff_time': '2023-05-08T14:00:00Z',
#   'team_h_score': 5,
#   'team_a_score': 3,
#   'round': 35,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': 111,
#   'selected': 15530,
#   'transfers_in': 264,
#   'transfers_out': 153},
#  {'element': 1,
#   'fixture': 360,
#   'opponent_team': 17,
#   'total_points': 0,
#   'was_home': False,
#   'kickoff_time': '2023-05-13T14:00:00Z',
#   'team_h_score': 0,
#   'team_a_score': 2,
#   'round': 36,
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'value': 42,
#   'transfers_balance': 42,
#   'selected': 15610,
#   'transfers_in': 180,
#   'transfers_out': 138}]
